# %%
# delete this cell if working on Pycharm
# !pip install Bio
# Out:
# Requirement already satisfied: Bio in /usr/local/lib/python3.11/dist-packages (1.8.0)
# Requirement already satisfied: biopython>=1.80 in /usr/local/lib/python3.11/dist-packages (from Bio) (1.85)
# Requirement already satisfied: gprofiler-official in /usr/local/lib/python3.11/dist-packages (from Bio) (1.0.0)
# Requirement already satisfied: mygene in /usr/local/lib/python3.11/dist-packages (from Bio) (3.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from Bio) (2.2.2)
# Requirement already satisfied: pooch in /usr/local/lib/python3.11/dist-packages (from Bio) (1.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from Bio) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from Bio) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython>=1.80->Bio) (2.0.2)
# Requirement already satisfied: biothings-client>=0.2.6 in /usr/local/lib/python3.11/dist-packages (from mygene->Bio) (0.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->Bio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch->Bio) (4.3.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from pooch->Bio) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->Bio) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->Bio) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->Bio) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->Bio) (2025.4.26)
# Requirement already satisfied: httpx>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from biothings-client>=0.2.6->mygene->Bio) (0.28.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->Bio) (1.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (4.13.2)

# %%
from Bio.PDB import *
import numpy as np
import os
from tqdm import tqdm
from Bio.Data.IUPACData import protein_letters_1to3_extended

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.listdir("/content/drive/MyDrive/Ex4Files"))
# Out:
# ['utils.ipynb', 'Ex4Data', '6xw6', 'train_labels.npy', 'train_input.npy', 'model_loss_history.png', 'trained_model.keras', 'net.ipynb']

# %%
NB_MAX_LENGTH = 140
AA_DICT = {"A": 0, "C": 1, "D": 2, "E": 3, "F": 4, "G": 5, "H": 6, "I": 7, "K": 8, "L": 9, "M": 10, "N": 11,
           "P": 12, "Q": 13, "R": 14, "S": 15, "T": 16, "W": 17, "Y": 18, "V": 19, "X": 20, "-": 21}
FEATURE_NUM = len(AA_DICT)
BACKBONE_ATOMS = ["N", "CA", "C", "O", "CB"]
OUTPUT_SIZE = len(BACKBONE_ATOMS) * 3
NB_CHAIN_ID = "H"

# %%
def get_seq_aa(pdb_file, chain_id):
    """
    returns the sequence (String) and a list of all the aa residue objects of the given protein chain.
    :param pdb_file: path to a pdb file
    :param chain_id: chain letter (char)
    :return: sequence, [aa objects]
    """
    # load model
    chain = PDBParser(QUIET=True).get_structure(pdb_file, pdb_file)[0][chain_id]

    aa_residues = []
    seq = ""

    for residue in chain.get_residues():
        aa = residue.get_resname()
        if not is_aa(aa) or not residue.has_id('CA'): # Not amino acid
            continue
        elif aa == "UNK":  # unkown amino acid
            seq += "X"
        else:
            # seq += Polypeptide.three_to_one(residue.get_resname())
            aa3 = residue.get_resname().capitalize()
            try:
                seq += protein_letters_3to1[aa3]
            except KeyError:
                seq += 'X'
        aa_residues.append(residue)

    return seq, aa_residues

# %%
def generate_input(pdb_file): #TODO: implement this!
    """
    receives a pdb file and returns its sequence in a one-hot encoding matrix (each row is an aa in the sequence, and
    each column represents a different aa out of the 20 aa + 2 special columns).
    :param pdb_file: path to a pdb file (nanobody, heavy chain has id 'H')
    :return: numpy array of shape (NB_MAX_LENGTH, FEATURE_NUM)
    """
    # get seq and aa residues
    seq, _ = get_seq_aa(pdb_file, NB_CHAIN_ID)

    # Convert the sequence string to a list of individual amino acid letters
    seq = list(seq)

    # Pad the sequence to NB_MAX_LENGTH using the '-' character
    if len(seq) < NB_MAX_LENGTH:
        seq += ['-'] * (NB_MAX_LENGTH - len(seq))
    else:
        seq = seq[:NB_MAX_LENGTH]

    # Initialize the one-hot encoding matrix with zeros
    one_hot_matrix = np.zeros((NB_MAX_LENGTH, FEATURE_NUM), dtype=np.float32)

    # Fill the one-hot matrix: set 1.0 in the column corresponding to each amino acid
    for i, aa in enumerate(seq):
        index = AA_DICT.get(aa, AA_DICT['X'])  # Default to 'X' if unknown
        one_hot_matrix[i, index] = 1.0

    return one_hot_matrix

# %%
def generate_label(pdb_file):  # TODO: implement this!
    """
    receives a pdb file and returns its backbone + CB coordinates.
    :param pdb_file: path to a pdb file (nanobody, heavy chain has id 'H') already alingned to a reference nanobody.
    :return: numpy array of shape (CDR_MAX_LENGTH, OUTPUT_SIZE).
    """
    # get seq and aa residues
    seq, aa_residues = get_seq_aa(pdb_file, NB_CHAIN_ID)

    # Initialize coordinate matrix with zeros
    label_matrix = np.zeros((NB_MAX_LENGTH, OUTPUT_SIZE), dtype=np.float32)

    # For each residue, extract coordinates for N, CA, C, O, CB atoms
    for i, (aa, residue) in enumerate(zip(seq, aa_residues)):
        if i >= NB_MAX_LENGTH:
            break  # Ignore residues beyond the max length

        atom_coords = []

        # Extract coordinates for atoms: N, CA, C, O
        for atom_name in ['N', 'CA', 'C', 'O']:
            try:
                coord = residue[atom_name].coord
            except KeyError:
                coord = np.array([0.0, 0.0, 0.0])  # Use (0,0,0) if atom is missing
            atom_coords.extend(coord)

        # Handle CB: Glycine doesn't have CB, use (0,0,0)
        if aa == 'G':
            cb_coord = [0.0, 0.0, 0.0]
        else:
            try:
                cb_coord = residue['CB'].coord
            except KeyError:
                cb_coord = [0.0, 0.0, 0.0]
        atom_coords.extend(cb_coord)

        # Add to matrix
        label_matrix[i] = atom_coords

    return label_matrix

    # TODO: fill the missing code lines.

# %%
def matrix_to_pdb(seq, coord_matrix, pdb_name):
    """
    Receives a sequence (String) and the output matrix of the neural network (coord_matrix, numpy array)
    and creates from them a PDB file named pdb_name.pdb.
    :param seq: protein sequence (String), with no padding
    :param coord_matrix: output np array of the nanobody neural network, shape = (NB_MAX_LENGTH, OUTPUT_SIZE)
    :param pdb_name: name of the output PDB file (String)
    """
    ATOM_LINE = "ATOM{}{}  {}{}{} {}{}{}{}{:.3f}{}{:.3f}{}{:.3f}  1.00{}{:.2f}           {}\n"
    END_LINE = "END\n"
    k = 1
    with open(f"{pdb_name}.pdb", "w") as pdb_file:
        for i, aa in enumerate(seq):
            third_space = (4 - len(str(i))) * " "
            for j, atom in enumerate(BACKBONE_ATOMS):
                if not (aa == "G" and atom == "CB"):  # GLY lacks CB atom
                    x, y, z = coord_matrix[i][3*j], coord_matrix[i][3*j+1], coord_matrix[i][3*j+2]
                    b_factor = 0.00
                    first_space = (7 - len(str(k))) * " "
                    second_space = (4 - len(atom)) * " "
                    forth_space = (12 - len("{:.3f}".format(x))) * " "
                    fifth_space = (8 - len("{:.3f}".format(y))) * " "
                    sixth_space = (8 - len("{:.3f}".format(z))) * " "
                    seventh_space = (6 - len("{:.2f}".format(b_factor))) * " "

                    residue_name = protein_letters_1to3_extended.get(aa.upper(), 'UNK')

                    pdb_file.write(ATOM_LINE.format(first_space, k, atom, second_space, residue_name , "H", third_space,
                                                    i, forth_space, x, fifth_space, y, sixth_space, z, seventh_space,
                                                    b_factor, atom[0]))
                    k += 1

        pdb_file.write(END_LINE)

# %%
if __name__ == '__main__':

   #  you can make all the data for the network in this section.
   # you can save the matrices to your drive and load them in your google colab file later.


    input_matrix = []
    labels_matrix = []
    data_path = "/content/drive/MyDrive/Ex4Files/Ex4Data"  # TODO: change path if needed

    for pdb in tqdm(os.listdir(data_path)):

        nb_one_hot = generate_input(os.path.join(data_path, pdb))
        nb_xyz = generate_label(os.path.join(data_path, pdb))

        input_matrix.append(nb_one_hot)
        labels_matrix.append(nb_xyz)

    save_path = "/content/drive/MyDrive/Ex4Files"  # TODO: change path if needed

    np.save(f"{save_path}/train_input.npy", np.array(input_matrix))
    np.save(f"{save_path}/train_labels.npy", np.array(labels_matrix))

    print(f"Number of samples: {len(input_matrix)}")
# Out:
# 100%|██████████| 1974/1974 [01:48<00:00, 18.27it/s]
# Number of samples: 1974
